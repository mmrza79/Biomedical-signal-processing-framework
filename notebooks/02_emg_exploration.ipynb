# %% [markdown]
# # 02 — sEMG exploration
#
# Purpose: visualize representative raw and processed sEMG only after dataset metadata and loader behavior are verified. No dataset is currently available, so this notebook intentionally produces no scientific plots.

# %%
from pathlib import Path

from src.data.loader import inspect_raw_dataset

repository_root = Path.cwd().resolve()
if repository_root.name == 'notebooks':
    repository_root = repository_root.parent
report = inspect_raw_dataset(repository_root / 'data' / 'raw')
if report.file_count == 0:
    print('No raw dataset files found. No plots generated.')
else:
    print('Files found. Verify schema and implement load_dataset() before plotting.')

# %% [markdown]
# ## Planned dataset-backed plots
#
# After integration, select a documented participant, recording, and channel. Plot raw sEMG, filtered sEMG, and optionally rectified sEMG against time. Every axis must state units from verified metadata. Then inspect signal distributions, channel comparisons, gait-phase counts, and participant counts. Do not use plots to choose preprocessing parameters on held-out test participants.

# %%
# TODO after verified loader integration:
# 1. Load one documented recording without modifying raw files.
# 2. Read sampling_frequency_hz and amplitude units from verified metadata.
# 3. Apply configured filters from src.preprocessing.filters.
# 4. Call plot_emg_processing(time_s, [raw, filtered, rectified], labels, amplitude_unit).
# 5. Plot phase and participant distributions using observed labels only.
